# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.chdir('/Users/mclevisachila/Downloads/')
movies_data = pd.read_excel('Movies_data_2000.xlsx')

# %%
movies_data
# Out:
#                                           Title     Budget      ID  \
# 0                                      Baywatch   69000000  339846
# 1                                      The Wall          0  405775
# 2                                        Gifted    7000000  400928
# 3                               The Spacewalker    7075038  440642
# 4                       The Fate of the Furious  250000000  337339
# ...                                         ...        ...     ...
# 4530                        Highlander: Endgame   25000000   12211
# 4531                                     Snatch   10000000     107
# 4532                                  Gladiator  103000000      98
# 4533                                  3 Strikes    6000000   47816
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000   22597
#
#      Original Language  Popularity Release Date     Revenue  Runtime  \
# 0                   en   35.637691   2017-12-05   177856751    116.0
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4535 entries, 0 to 4534
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              4535 non-null   object
#  1   Budget             4535 non-null   int64
#  2   ID                 4535 non-null   int64
#  3   Original Language  4535 non-null   object
#  4   Popularity         4535 non-null   float64
#  5   Release Date       4535 non-null   datetime64[ns]
#  6   Revenue            4535 non-null   int64
#  7   Runtime            4532 non-null   float64
#  8   Vote Average       4535 non-null   float64
#  9   Vote Count         4535 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(2)
# memory usage: 354.4+ KB

# %%
duplicates=movies_data.duplicated().sum()

# %%
duplicates
# Out:
# 2

# %%
duplicates=movies_data.drop_duplicates()

# %%
duplicates
# Out:
#                                           Title     Budget      ID  \
# 0                                      Baywatch   69000000  339846
# 1                                      The Wall          0  405775
# 2                                        Gifted    7000000  400928
# 3                               The Spacewalker    7075038  440642
# 4                       The Fate of the Furious  250000000  337339
# ...                                         ...        ...     ...
# 4530                        Highlander: Endgame   25000000   12211
# 4531                                     Snatch   10000000     107
# 4532                                  Gladiator  103000000      98
# 4533                                  3 Strikes    6000000   47816
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000   22597
#
#      Original Language  Popularity Release Date     Revenue  Runtime  \
# 0                   en   35.637691   2017-12-05   177856751    116.0
# ...

# %%
# missing values
missing_values=movies_data.isna().sum()

# %%
missing_values
# Out:
# Title                0
# Budget               0
# ID                   0
# Original Language    0
# Popularity           0
# Release Date         0
# Revenue              0
# Runtime              3
# Vote Average         0
# Vote Count           0
# dtype: int64

# %%
movies_data['Runtime'].fillna(movies_data['Runtime'].mean(), inplace=True)

# %%
movies_data.head(10)
# Out:
#                             Title     Budget      ID Original Language  \
# 0                        Baywatch   69000000  339846                en
# 1                        The Wall          0  405775                en
# 2                          Gifted    7000000  400928                en
# 3                 The Spacewalker    7075038  440642                ru
# 4         The Fate of the Furious  250000000  337339                en
# 5                       Sleepless   30000000  324542                en
# 6                 The Bye Bye Man    7400000  292280                en
# 7                        Bairavaa          0  411717                ta
# 8                       Good Time          0  429200                en
# 9  War for the Planet of the Apes  152000000  281338                en
#
#    Popularity Release Date     Revenue  Runtime  Vote Average  Vote Count  \
# 0   35.637691   2017-12-05   177856751    116.0           6.1        1829
# ...

# %%
movies_data.describe()
# Out:
#              Budget             ID   Popularity       Revenue      Runtime  \
# count  4.535000e+03    4535.000000  4535.000000  4.535000e+03  4535.000000
# mean   2.865935e+07   96240.325028     9.311619  8.266938e+07   107.489629
# std    4.296899e+07  115101.300157    14.733265  1.700826e+08    21.075842
# min    0.000000e+00      12.000000     0.001272  1.000000e+00     0.000000
# 25%    5.250000e+01   11055.000000     4.666667  1.749329e+06    94.000000
# 50%    1.200000e+07   42399.000000     7.825072  1.912540e+07   104.000000
# 75%    3.700000e+07  153338.000000    11.261433  8.526087e+07   118.000000
# max    3.800000e+08  443319.000000   547.488298  2.787965e+09   338.000000
#
#        Vote Average    Vote Count
# count   4535.000000   4535.000000
# mean       6.186218    699.371555
# std        0.988983   1257.936544
# min        0.000000      0.000000
# 25%        5.700000     58.500000
# 50%        6.200000    232.000000
# 75%        6.800000    730.000000
# ...

# %%
# Extracting year from release date
movies_data['Release Year'] = movies_data['Release Date'].dt.year

# %%
# movies release per year.
movies_per_year = movies_data['Release Year'].value_counts().sort_index()
movies_per_year
# Out:
# 2000    155
# 2001    177
# 2002    201
# 2003    180
# 2004    209
# 2005    236
# 2006    281
# 2007    258
# 2008    266
# 2009    284
# 2010    306
# 2011    312
# 2012    305
# 2013    337
# 2014    321
# 2015    310
# 2016    299
# 2017     98
# Name: Release Year, dtype: int64

# %%
# line chart showing the number of movies release in each year.

plt.figure(figsize=(12, 6))
plt.plot(movies_per_year.index, movies_per_year.values, marker='o', linestyle='-', color='b')
plt.title('Number of Movies Released Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Runtime movie distribution

plt.figure(figsize=(10, 6))
sns.histplot(movies_data['Runtime'], bins=30, kde=True)
plt.title('Distribution of Movie Runtime')
plt.xlabel('Runtime')
plt.ylabel('Frequency')
plt.show()

# %%
revenue=movies_data[['Title','Revenue','Release Year']]
revenue = revenue.sort_values(by='Revenue', ascending=False)

# %%
revenue.head(20)
# Out:
#                                               Title     Revenue  Release Year
# 2347                                         Avatar  2787965087          2009
# 413                    Star Wars: The Force Awakens  2068223624          2015
# 1586                                   The Avengers  1519557910          2012
# 509                                  Jurassic World  1513528810          2015
# 706                                       Furious 7  1506249360          2015
# 624                         Avengers: Age of Ultron  1405403694          2015
# 1838   Harry Potter and the Deathly Hallows: Part 2  1342000000          2011
# 1058                                         Frozen  1274219009          2013
# 69                             Beauty and the Beast  1262886337          2017
# 4                           The Fate of the Furious  1238764765          2017
# 1277                                     Iron Man 3  1215439994          2013
# ...

# %%
revenue_by_year = movies_data.groupby('Release Year')['Revenue'].sum().sort_values(ascending=False)
revenue_by_year
# Out:
# Release Year
# 2016    30497876509
# 2015    28819362583
# 2013    26667698390
# 2014    26443396645
# 2012    26058753190
# 2011    24279042189
# 2010    23447174910
# 2009    23370045875
# 2008    20655226307
# 2007    19703494110
# 2006    18368625314
# 2004    17666133892
# 2005    16812936570
# 2003    15767126067
# 2002    15523789818
# 2017    15075894975
# 2001    14133875315
# 2000    11615202900
# Name: Revenue, dtype: int64

# %%
highest_revenue = revenue_by_year.max()
highest_revenue
# Out:
# 30497876509

# %%
plt.figure(figsize=(12, 6))
plt.plot(revenue_by_year.index, revenue_by_year.values, marker='o', linestyle='-', color='b')
plt.title('Total Revenue by Year')
plt.xlabel('Year')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(False)
plt.show()
